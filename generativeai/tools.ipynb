# %% [markdown]
# ## Tools
# ## Models can request to call tools that perform task such as fetching data from a database, searching the web, or running code. Tools are pairing of:
# ## 1. A schema, including the name of the tool, a description and/or arguments definition (often a JSON schema)
# ## 2. A function or coroutine to execute.

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:llama-3.3-70b-versatile")

response = model.invoke("Write me an essay on AI")
response
print(response)
# Out:
# content='The Rise of Artificial Intelligence: A New Era of Human Innovation\n\nArtificial Intelligence (AI) has been a topic of fascination and debate for decades. From its humble beginnings in the mid-20th century to the current era of rapid advancements, AI has evolved significantly, transforming the way we live, work, and interact with each other. Today, AI is no longer just a science fiction concept, but a reality that is changing the world at an unprecedented pace.\n\nThe term "Artificial Intelligence" was first coined in 1956 by John McCarthy, a computer scientist and cognitive scientist. McCarthy defined AI as "the science and engineering of making intelligent machines, especially intelligent computer programs." Since then, AI has undergone significant developments, with researchers and scientists working tirelessly to create machines that can think, learn, and act like humans. The goal of AI is to create intelligent systems that can perform tasks that typically require human intelligence, such as reasoning, problem-solving, and decision-making.\n\nOne of the most significant advancements in AI has been the development of machine learning algorithms. Machine learning is a subset of AI that enables computers to learn from data without being explicitly programmed. This has led to the creation of AI systems that can recognize patterns, classify objects, and make predictions with unprecedented accuracy. For example, image recognition systems can identify objects, people, and animals with remarkable precision, while natural language processing systems can understand and respond to human language.\n\nThe applications of AI are vast and diverse, ranging from healthcare and finance to education and transportation. In healthcare, AI-powered systems can analyze medical images, diagnose diseases, and develop personalized treatment plans. In finance, AI can detect fraud, predict stock market trends, and optimize investment portfolios. In education, AI can create personalized learning plans, grade assignments, and provide real-time feedback to students. In transportation, AI can optimize traffic flow, predict maintenance needs, and develop autonomous vehicles.\n\nHowever, the rise of AI has also raised concerns about its impact on society. One of the most significant concerns is the potential for job displacement, as AI systems automate tasks that were previously performed by humans. According to a report by the McKinsey Global Institute, up to 800 million jobs could be lost worldwide due to automation by 2030. Another concern is the potential for AI to exacerbate existing social biases, such as racism and sexism, if the data used to train AI systems is biased.\n\nDespite these concerns, the benefits of AI far outweigh the risks. AI has the potential to solve some of the world\'s most pressing problems, such as climate change, poverty, and inequality. For example, AI-powered systems can analyze climate data, predict weather patterns, and develop sustainable energy solutions. AI can also help bridge the gap in healthcare, education, and economic opportunities, especially in underserved communities.\n\nIn conclusion, the rise of AI marks a new era of human innovation, with the potential to transform every aspect of our lives. While there are concerns about the impact of AI on society, the benefits of AI far outweigh the risks. As we move forward, it is essential to develop AI systems that are transparent, accountable, and aligned with human values. By doing so, we can harness the power of AI to create a better future for all, where humans and machines work together to solve the world\'s most pressing problems.\n\nThe future of AI is exciting and uncertain, with new breakthroughs and innovations emerging every day. As we continue to push the boundaries of what is possible with AI, we must also ensure that we are using this technology responsibly and for the greater good. By doing so, we can create a world where AI enhances human life,  ...

# %%
## Tools

from langchain.tools import tool

@tool
def get_weather(location: str) -> str:
    """Get the weather for a location."""
    return f"The weather in {location} is sunny."

model_with_tools =model.bind_tools([get_weather])

# %%
response = model_with_tools.invoke("what's weather of Panvel")
print(response)
# Out:
# content='' additional_kwargs={'tool_calls': [{'id': 'thfm1wjhc', 'function': {'arguments': '{"location":"Panvel"}', 'name': 'get_weather'}, 'type': 'function'}]} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 218, 'total_tokens': 233, 'completion_time': 0.042201478, 'completion_tokens_details': None, 'prompt_time': 0.010842119, 'prompt_tokens_details': None, 'queue_time': 0.04950027, 'total_time': 0.053043597}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019ccc5b-fb59-7630-8cce-b269d98a08f9-0' tool_calls=[{'name': 'get_weather', 'args': {'location': 'Panvel'}, 'id': 'thfm1wjhc', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 218, 'output_tokens': 15, 'total_tokens': 233}

# %%
response.tool_calls
# Out:
# [{'name': 'get_weather',
#   'args': {'location': 'Panvel'},
#   'id': 'thfm1wjhc',
#   'type': 'tool_call'}]
